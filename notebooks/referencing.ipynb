# %% [markdown]
# # Relative References in JSON Schema
# With recent updates to the schema build structure, GKM schemas now exist across multiple, cross-referenced files in the schema directory, including imports from other upstream sources.
#
# To handle this, schemas need to have their '$id' attribute set.
#
# First, a look at the situation _without_ doing so:

# %%
import re
from pathlib import Path
import jsonschema as js
import json
import os

root_dir = Path(os.getcwd()).parent
SCHEMA_DIR = root_dir / "schema"
vrs_jsons_path = SCHEMA_DIR / "vrs" /  "json"

# %%
sl_schema_filepath = vrs_jsons_path / 'SequenceLocation'
sl = {
    'sequenceReference': {
        'refgetAccession': 'SQ.9W6SPR3RMCHWCSGJLQHE6KBOD285V5SW',
        'type':'SequenceReference'
    },
    'start': 100,
    'end': [None, 150],
    'type': 'SequenceLocation'
}

with open(sl_schema_filepath, 'r') as sl_js_file:
    sl_schema = json.load(sl_js_file)
js.validate(sl, sl_schema)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/git/vrs/venv/lib/python3.12/site-packages/referencing/_core.py:417, in Registry.get_or_retrieve(self, uri)
#     416 try:
# --> 417     resource = registry._retrieve(uri)
#     418 except (
#     419     exceptions.CannotDetermineSpecification,
#     420     exceptions.NoSuchResource,
#     421 ):
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/validators.py:112, in _warn_for_remote_retrieve(uri)
#     111 request = Request(uri, headers=headers)  # noqa: S310
# --> 112 with urlopen(request) as response:  # noqa: S310
#     113     warnings.warn(
#     114         "Automatically retrieving remote references can be a security "
#     115         "vulnerability and is discouraged by the JSON Schema "
#    (...)
#     123         stacklevel=9,  # Ha ha ha ha magic numbers :/
#     124     )
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/urllib/request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/urllib/request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/urllib/request.py:559, in OpenerDirector.error(self, proto, *args)
#     558 args = (dict, 'default', 'http_error_default') + orig_args
# --> 559 return self._call_chain(*args)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     491 func = getattr(handler, meth_name)
# --> 492 result = func(*args)
#     493 if result is not None:
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/urllib/request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
#
# The above exception was the direct cause of the following exception:
#
# Unretrievable                             Traceback (most recent call last)
# File ~/git/vrs/venv/lib/python3.12/site-packages/referencing/_core.py:667, in Resolver.lookup(self, ref)
#     666 try:
# --> 667     retrieved = self._registry.get_or_retrieve(uri)
#     668 except exceptions.NoSuchResource:
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/referencing/_core.py:424, in Registry.get_or_retrieve(self, uri)
#     423 except Exception as error:  # noqa: BLE001
# --> 424     raise exceptions.Unretrievable(ref=uri) from error
#     425 else:
#
# Unretrievable: 'https://w3id.org/ga4gh/schema/vrs/2.x/json/SequenceReference'
#
# The above exception was the direct cause of the following exception:
#
# Unresolvable                              Traceback (most recent call last)
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/validators.py:450, in create.<locals>.Validator._validate_reference(self, ref, instance)
#     449 try:
# --> 450     resolved = self._resolver.lookup(ref)
#     451 except referencing.exceptions.Unresolvable as err:
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/referencing/_core.py:671, in Resolver.lookup(self, ref)
#     670 except exceptions.Unretrievable as error:
# --> 671     raise exceptions.Unresolvable(ref=ref) from error
#     673 if fragment.startswith("/"):
#
# Unresolvable: SequenceReference
#
# The above exception was the direct cause of the following exception:
#
# _WrappedReferencingError                  Traceback (most recent call last)
# Cell In[38], line 14
#      12 with open(sl_schema_filepath, 'r') as sl_js_file:
#      13     sl_schema = json.load(sl_js_file)
# ---> 14 js.validate(sl, sl_schema)
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/validators.py:1310, in validate(instance, schema, cls, *args, **kwargs)
#    1308 cls.check_schema(schema)
#    1309 validator = cls(schema, *args, **kwargs)
# -> 1310 error = exceptions.best_match(validator.iter_errors(instance))
#    1311 if error is not None:
#    1312     raise error
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/exceptions.py:458, in best_match(errors, key)
#     420 """
#     421 Try to find an error that appears to be the best match among given errors.
#     422
#    (...)
#     455     set of inputs from version to version if better heuristics are added.
#     456 """
#     457 errors = iter(errors)
# --> 458 best = next(errors, None)
#     459 if best is None:
#     460     return
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/validators.py:371, in create.<locals>.Validator.iter_errors(self, instance, _schema)
#     368     continue
#     370 errors = validator(self, v, instance, _schema) or ()
# --> 371 for error in errors:
#     372     # set details if not already set by the called fn
#     373     error._set(
#     374         validator=k,
#     375         validator_value=v,
#    (...)
#     378         type_checker=self.TYPE_CHECKER,
#     379     )
#     380     if k not in {"if", "$ref"}:
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/_keywords.py:296, in properties(validator, properties, instance, schema)
#     294 for property, subschema in properties.items():
#     295     if property in instance:
# --> 296         yield from validator.descend(
#     297             instance[property],
#     298             subschema,
#     299             path=property,
#     300             schema_path=property,
#     301         )
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/validators.py:419, in create.<locals>.Validator.descend(self, instance, schema, path, schema_path, resolver)
#     416     continue
#     418 errors = validator(evolved, v, instance, schema) or ()
# --> 419 for error in errors:
#     420     # set details if not already set by the called fn
#     421     error._set(
#     422         validator=k,
#     423         validator_value=v,
#    (...)
#     426         type_checker=evolved.TYPE_CHECKER,
#     427     )
#     428     if k not in {"if", "$ref"}:
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/_keywords.py:355, in oneOf(validator, oneOf, instance, schema)
#     353 all_errors = []
#     354 for index, subschema in subschemas:
# --> 355     errs = list(validator.descend(instance, subschema, schema_path=index))
#     356     if not errs:
#     357         first_valid = subschema
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/validators.py:419, in create.<locals>.Validator.descend(self, instance, schema, path, schema_path, resolver)
#     416     continue
#     418 errors = validator(evolved, v, instance, schema) or ()
# --> 419 for error in errors:
#     420     # set details if not already set by the called fn
#     421     error._set(
#     422         validator=k,
#     423         validator_value=v,
#    (...)
#     426         type_checker=evolved.TYPE_CHECKER,
#     427     )
#     428     if k not in {"if", "$ref"}:
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/_keywords.py:275, in ref(validator, ref, instance, schema)
#     274 def ref(validator, ref, instance, schema):
# --> 275     yield from validator._validate_reference(ref=ref, instance=instance)
#
# File ~/git/vrs/venv/lib/python3.12/site-packages/jsonschema/validators.py:452, in create.<locals>.Validator._validate_reference(self, ref, instance)
#     450         resolved = self._resolver.lookup(ref)
#     451     except referencing.exceptions.Unresolvable as err:
# --> 452         raise exceptions._WrappedReferencingError(err) from err
#     454     return self.descend(
#     455         instance,
#     456         resolved.contents,
#     457         resolver=resolved.resolver,
#     458     )
#     459 else:
#
# _WrappedReferencingError: Unresolvable: SequenceReference

# %% [markdown]
# The `_WrappedReferencingError` informs us that, without an anchor provided by `$id`, there is no way to resolve the relative references. This makes sense, since the system has no idea where the loaded JSON came from!
#
# We can address this by using the `referencing` library and pre-loading all of our schemas:

# %%
from referencing import Registry, Resource
from referencing.jsonschema import DRAFT202012
from jsonschema import Draft202012Validator
import re

# %%
ga4gh_re = re.compile(r'.*\/ga4gh\/schema\/([\w\-\.]+)\/[\w\.]+\/(.*)$')

def retrieve_rel_ref(ga4gh_ref: str):
    ga4gh_match = ga4gh_re.match(ga4gh_ref)
    if ga4gh_match is None:
        raise ValueError(f'ga4gh_ref {ga4gh_ref} is not a root GA4GH reference')
    schema_module = ga4gh_match.group(1)
    local_path = ga4gh_match.group(2)
    resolved_path = (SCHEMA_DIR / schema_module / local_path).resolve()
    schema = json.loads(resolved_path.read_text())
    return Resource.from_contents(schema)


vrs_js_registry = Registry(retrieve=retrieve_rel_ref)
vrs_js = dict()
vrs_validator = dict()

for schema_path in vrs_jsons_path.glob('*'):
    content = json.loads(schema_path.read_text())
    schema_uri = schema_path.as_uri()
    content['id'] = schema_uri
    schema_resource = Resource(contents=content, specification=DRAFT202012)
    vrs_js[schema_path.stem] = content
    vrs_schemas = vrs_js_registry.with_resources([
        (schema_path.name, schema_resource),
        (schema_uri, schema_resource)
    ])

for cls in vrs_js:
    vrs_validator[cls] = Draft202012Validator(vrs_js[cls], registry=vrs_js_registry)

# %% [markdown]
# Now we can validate! Calls to refs from the JSONs directory are retrievable from the registry, and relative refs outside of the VRS JSONs are handled by the `retrieve_rel_ref` method.

# %%
vrs_validator['SequenceLocation'].validate(sl)

# %%
a = {
    'location': sl,
    'state': {
        'type': 'ReferenceLengthExpression',
        'length': [32, 35],
        'repeatSubunitLength': 3
    },
    'type': 'Allele'
}
vrs_validator['Allele'].validate(a)
