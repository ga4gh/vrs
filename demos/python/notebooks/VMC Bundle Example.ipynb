# %% [markdown]
# # VMC Bundle Example
# This example shows how to use VMC in the context of application-defined annotations

# %%
import json

from vmcdemo import models

bundle_fn = "ApoE Example.vmc.json"

# %%
vmcbundle = models.Vmcbundle(**json.load(open(bundle_fn)))
